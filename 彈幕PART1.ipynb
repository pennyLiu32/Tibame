# %% [markdown]
# <a href="https://colab.research.google.com/github/pennyLiu32/Tibame/blob/main/%E5%BD%88%E5%B9%95PART1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import json
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=24817&geo=TW%2CHK"
f = req.urlopen(url)
# list + dict: JSON格式
content = f.read()

content = json.loads(content)
# print(type(content))
danmus = content["data"]["danmu"]
for d in danmus:
    uid = d["userid"]
    text = d["text"]
    # print(uid, text)

# 想把JSON格式存成檔案
# f = open("test.json", "w", encoding="utf-8")
# json.dump(danmus, f, ensure_ascii=False, indent=4)
# f.close

# with open("test.json", "w", encoding="utf-8")as f:
    # json.dump(danmus, f, ensure_ascii=False, indent=4)


# csv(comma-separated values): 標準表格格式
# 用,隔開 ex:姓名,身高
# Elwing,175
# "Elwing, Mr. Chou",180
# JSON格式也可以被視為一種表格: [{}, {}]
# 用pandas前先記得: DataFrae型態(自訂表格型態)
df = pd.DataFrame(danmus)
df.to_csv("baha.csv", encoding="utf-8", index=False)
df
# Out:
#                           text    color  size  position   time        sn  \
# 0            這部應該是新版原創電影當中最好的吧  #FFFFFF     1         0     15  22772800
# 1                         來了來了  #FFFFFF     1         0     15  22799260
# 2                            簽  #FFFFFF     1         0     20  47816968
# 3                           之一  #FFFFFF     1         0     25  22772806
# 4    重刷好多遍啦~這是我最愛的一部~簽2026/7/6  #FFFFFF     1         0     41  49726869
# ..                         ...      ...   ...       ...    ...       ...
# 811                ♪君だけが，君だけが♪  #00C3FC     1         1  59830  23302850
# 812            納豆、炸雞、蛋糕口味刨冰...  #FFFFFF     1         0  59861  25153665
# 813                ♪僕の心をつくるんだ♪  #00C3FC     1         1  59867  23302856
# 814                       ♪ねぇ♪  #00C3FC     1         1  59904  23302864
# 815                ♪僕の心をつくってよ♪  #00C3FC     1         1  59940  23302869
#
#           userid
# 0    wythe730123
# 1           A323
# 2         wtfgun
# 3    wythe730123
# 4     p226930263
# ..           ...
# 811  creeper0714
# 812   jack246800
# 813  creeper0714
# 814  creeper0714
# 815  creeper0714
#
# [816 rows x 7 columns]
