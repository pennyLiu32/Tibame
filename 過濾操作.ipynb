# %% [markdown]
# <a href="https://colab.research.google.com/github/pennyLiu32/Tibame/blob/main/%E9%81%8E%E6%BF%BE%E6%93%8D%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 在每一個html區塊上面，都會有機會看到class這屬性
#     - class: 是拿來排版的
#
# - 整個網頁架構分成
#     - 前端:
#         - 秀出回應
#             - HTML: 內容
#             - CSS: 讓你的html區塊有排版(重要!!!)
#             - Javascript程式語言: 讓你的網頁動起來(大部分情況不用管)
#
#     - 後端:
#         - 當網址來得時候你要收(nginx)
#         - 處理(需要一程式，如果是python Flask Django
#         FastAPI)
#         - 查資料庫
#         - 把回應送回去(網頁、JSON)
#
# - 靜態網頁/動態網頁(x) -> 到底哪個網址才是重點!!!
#
# ```
# 1. 透過html區塊名字給出排版
# a{
#     background-color:red;
# }
#
# 為了能夠去選擇我們要的那些對象，我們就給那些對象加入一個class html屬性
# class="分類1 分類2 分類3"
# 2. 透過class名字去篩選
# .分類{
#
# }
#
# js-thumbnail-img{
#     border-radius:50%
# }
#
#
# id="unique_value"
# 3. 透過id去篩選
# #id{
#
# }
# ```

# %%
import urllib.request as req
import bs4 as bs

url = "https://tabelog.com/tw/kagoshima/rstLst/washoku/"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)
rs = html.find_all("div", {"class":"list-rst__body"})
for r in rs:
    # 拿取東西
    name = r.find("a", {"class":"list-rst__rst-name-target"})
    area_genre = r.find("div", {"class":"list-rst__area-genre"})
    rating = r.find("span", {"class":"list-rst__rating-val"})
    prices = r.find_all("span", {"class":"c-rating-v3__val"})
    lunch_price = prices[1]
    dinner_price = prices[0]
    holiday = r.find("span", {"class":"list-rst__holiday-text"})


    # 區塊萃取
    name_href = name["href"]
    name_text = name.get_text()
    area_genre_text = area_genre.get_text().strip()
    rating_text = rating.get_text()
    lunch_price_text = lunch_price.get_text().strip()
    dinner_price_text = dinner_price.get_text().strip()
    holiday_text = holiday.get_text().strip()

    # 印出來
    print(name_href)
    print(name_text)
    print(area_genre_text)
    print(rating_text)
    print(lunch_price_text)
    print(dinner_price_text)
    print(holiday_text)
    print("-"*30)
# Out:
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000653/
# Miyama本舖 天文館店
# 天文館通車站 219m / 居酒屋 (酒館), 烤雞肉串, 燒肉
# 3.40
# -
# JPY 4,000 - JPY 4,999
# 星期日
# ------------------------------
# https://tabelog.com/tw/kagoshima/A4601/A460101/46016654/
# 壽司處 Kimiya
# 脇田車站 27m / 壽司
# 3.74
# JPY 4,000 - JPY 4,999
# JPY 5,000 - JPY 5,999
# 星期三, 星期四
# ------------------------------
# https://tabelog.com/tw/kagoshima/A4601/A460101/46005583/
# 鹿兒島黑豚 六白亭
# 高見橋車站 353m / 涮涮鍋, 居酒屋 (酒館), 炸豬排
# 3.48
# JPY 1,000 - JPY 1,999
# JPY 3,000 - JPY 3,999
# -
# ------------------------------
# https://tabelog.com/tw/kagoshima/A4601/A460101/46010197/
# Mikan
# 天文館通車站 237m / 居酒屋 (酒館), 涮涮鍋, 郷土料理
# 3.37
# -
# JPY 4,000 - JPY 4,999
# 星期日
# ------------------------------
# https://tabelog.com/tw/kagoshima/A4601/A460101/46014561/
# 豬排與、涮涮鍋。黑豚Fukuya
# 天文館通車站 52m / 炸豬排, 涮涮鍋, 日式火鍋
# 3.76
# JPY 1,000 - JPY 1,999
# JPY 4,000 - JPY 4,999
# -
# ------------------------------
# https://tabelog.com/tw/kagoshima/A4601/A460101/46