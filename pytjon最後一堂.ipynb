# %% [markdown]
# <a href="https://colab.research.google.com/github/pennyLiu32/Tibame/blob/main/pytjon%E6%9C%80%E5%BE%8C%E4%B8%80%E5%A0%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 從無到有的表格
#     - JSON -> Dataframe
#     - JSON: [{}, {}, {}]

# %%
import urllib.request as req
import bs4 as bs

def download_page(page):
  url = f"https://tabelog.com/tw/kagoshima/rstLst/{page}/"
  resp = req.urlopen(url)
  content = resp.read()
  html = bs.BeautifulSoup(content)
  rs = html.find_all("div", {"class":"list-rst__body"})

  # 準備一個table
  table = []
  for r in rs:
    name = r.find("a", {"class":"list-rst__rst-name-target"})
    area_genre = r.find("div", {"class":"list-rst__area-genre"})
    rating = r.find("span", {"class":"list-rst__rating-val"})
    prices = r.find_all("span", {"class":"c-rating-v3__val"})
    lunch_price = prices[1]
    dinner_price = prices[0]
    holiday = r.find("span", {"class":"list-rst__holiday-text"})

    name_href = name["href"]
    name_text = name.get_text()
    area_genre_text = area_genre.get_text().strip()
    rating_text = rating.get_text()
    lunch_price_text = lunch_price.get_text().strip()
    dinner_price_text = dinner_price.get_text().strip()
    holiday_text = holiday.get_text().strip()

    # 每一筆資料都是一個字典
    data = {
      "rating": rating_text,
      "name": name_text,
      "link": name_href,
      "area_genre": area_genre_text,
      "price_lunch": lunch_price_text,
      "price_dinner": dinner_price_text,
      "holiday": holiday_text,
    }
    table.append(data)

  return table
download_page(2)
# Out:
# [{'rating': '3.59',
#   'name': '燒肉上畜',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016492/',
#   'area_genre': '都通車站 90m / 燒肉, 內臟類, 韓國料理',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 6,000 - JPY 7,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': 'Mifuku',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018865/',
#   'area_genre': '都通車站 105m / 壽喜燒, 涮涮鍋, 炸豬排',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 8,000 - JPY 9,999',
#   'holiday': '-'},
#  {'rating': '3.52',
#   'name': '豬排和涮涮鍋。黑豬福屋 本店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018051/',
#   'area_genre': '天文館通車站 192m / 炸豬排, 涮涮鍋, 豬肉涮涮鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.54',
#   'name': '吾愛人 中央站東口店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46008602/',
#   'area_genre': '高見橋車站 45m / 居酒屋 (酒館), 涮涮鍋, 炸豬排',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '星期一'},
#  {'rating': '3.29',
#   'name': '薩摩 黑豬百寛',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46003354/',
#   'area_genre': '鹿兒島中央車站 289m / 居酒屋 (酒館), 涮涮鍋, 海鮮',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.15',
#   'name': '日本料理 石原',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46011168/',
#   'area_genre': '朝日通車站 467m / 日本料理, 郷土料理',
#   'price_lunch': 'JPY 3,000 - JPY 3,999',
#   'price_dinner': 'JPY 8,000 - JPY 9,999',
#   'holiday': '星期三'},
#  {'rating': '3.03',
#   'name': '鐵板燒 海雲',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016551/',
#   'area_genre': '郡元車站 1286m / 鐵板燒, 牛排, 漢堡排',
#   'price_lunch': 'JPY 5,000 - JPY 5,999',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.31',
#   'name': '魚菜屋 朝次郎 AMU PLAZA鹿兒島店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46000107/',
#   'area_genre': '鹿兒島中央站前車站 130m / 居酒屋 (酒館), 海鮮, 海鮮蓋飯',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 2,000 - JPY 2,999',
#   'holiday': '-'},
#  {'rating': '3.32',
#   'name': '定食飯男',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016534/',
#   'area_genre': '高见马场車站 114m / 食堂, 海鮮, 居酒屋 (酒館)',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期三'},
#  {'rating': '3.18',
#   'name': '鹿兒島黑豚涮涮鍋專門店 黑之極',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46017586/',
#   'area_genre': '天文館通車站 291m / 涮涮鍋, 居酒屋 (酒館), 日式火鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.06',
#   'name': '炭火燒肉內臟 Yokozuna Sanshirou 天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46015289/',
#   'area_genre': '天文館通車站 240m / 燒肉, 居酒屋 (酒館), 便當',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期三'},
#  {'rating': '3.07',
#   'name': '鹿兒島劇場',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46017452/',
#   'area_genre': '天文館通車站 210m / 居酒屋 (酒館), 海鮮, 涮涮鍋',
#   'price_lunch': 'JPY 2,000 - JPY 2,999',
#   'price_dinner': 'JPY 2,000 - JPY 2,999',
#   'holiday': '-'},
#  {'rating': '3.02',
#   'name': '西鄉Don 東千石店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018322/',
#   'area_genre': '高见马场車站 177m / 居酒屋 (酒館), 炸豬排, 壽司',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期一'},
#  {'rating': '3.17',
#   'name': '包廂燒肉 牛道 Hanare',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46012415/',
#   'area_genre': '天文館通車站 224m / 燒肉, 涮涮鍋, 壽喜燒',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.05',
#   'name': '全席個室居酒屋 Wa none 鹿兒島天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46014385/',
#   'area_genre': '天文館通車站 139m / 居酒屋 (酒館), 海鮮, 日式火鍋',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': '鹿兒島縣產A5等級黑毛和牛 全席完全個室 牛一彩 天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46010542/',
#   'area_genre': '天文館通車站 367m / 燒肉, 壽喜燒, 涮涮鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 5,000 - JPY 5,999',
#   'holiday': '-'},
#  {'rating': '3.35',
#   'name': 'Miyama本舖 國分店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4603/A460301/46001667/',
#   'area_genre': '國分車站 708m / 居酒屋 (酒館), 烤雞肉串, 燒肉',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': '鐵板 薊 鹿兒島店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016951/',
#   'area_genre': '天文館通車站 76m / 居酒屋 (酒館), 鐵板燒, 海鮮',
#   'price_lunch': 'JPY 3,000 - JPY 3,999',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.56',
#   'name': '太郎壽司',
#   'link': 'https://tabelog.com/tw/kagoshima/A4602/A460203/46002327/',
#   'area_genre': '阿久根車站 310m / 壽司, 海鮮, 鰻魚',
#   'price_lunch': 'JPY 2,000 - JPY 2,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.39',
#   'name': '燒酎 酒々藏',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46000160/',
#   'area_genre': '天文館通車站 189m / 居酒屋 (酒館), 海鮮, 郷土料理',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期日'}]
# [{'rating': '3.59',
#   'name': '燒肉上畜',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016492/',
#   'area_genre': '都通車站 90m / 燒肉, 內臟類, 韓國料理',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 6,000 - JPY 7,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': 'Mifuku',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018865/',
#   'area_genre': '都通車站 105m / 壽喜燒, 涮涮鍋, 炸豬排',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 8,000 - JPY 9,999',
#   'holiday': '-'},
#  {'rating': '3.52',
#   'name': '豬排和涮涮鍋。黑豬福屋 本店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018051/',
#   'area_genre': '天文館通車站 192m / 炸豬排, 涮涮鍋, 豬肉涮涮鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.54',
#   'name': '吾愛人 中央站東口店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46008602/',
#   'area_genre': '高見橋車站 45m / 居酒屋 (酒館), 涮涮鍋, 炸豬排',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '星期一'},
#  {'rating': '3.29',
#   'name': '薩摩 黑豬百寛',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46003354/',
#   'area_genre': '鹿兒島中央車站 289m / 居酒屋 (酒館), 涮涮鍋, 海鮮',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.15',
#   'name': '日本料理 石原',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46011168/',
#   'area_genre': '朝日通車站 467m / 日本料理, 郷土料理',
#   'price_lunch': 'JPY 3,000 - JPY 3,999',
#   'price_dinner': 'JPY 8,000 - JPY 9,999',
#   'holiday': '星期三'},
#  {'rating': '3.03',
#   'name': '鐵板燒 海雲',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016551/',
#   'area_genre': '郡元車站 1286m / 鐵板燒, 牛排, 漢堡排',
#   'price_lunch': 'JPY 5,000 - JPY 5,999',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.31',
#   'name': '魚菜屋 朝次郎 AMU PLAZA鹿兒島店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46000107/',
#   'area_genre': '鹿兒島中央站前車站 130m / 居酒屋 (酒館), 海鮮, 海鮮蓋飯',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 2,000 - JPY 2,999',
#   'holiday': '-'},
#  {'rating': '3.32',
#   'name': '定食飯男',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016534/',
#   'area_genre': '高见马场車站 114m / 食堂, 海鮮, 居酒屋 (酒館)',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期三'},
#  {'rating': '3.18',
#   'name': '鹿兒島黑豚涮涮鍋專門店 黑之極',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46017586/',
#   'area_genre': '天文館通車站 291m / 涮涮鍋, 居酒屋 (酒館), 日式火鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.06',
#   'name': '炭火燒肉內臟 Yokozuna Sanshirou 天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46015289/',
#   'area_genre': '天文館通車站 240m / 燒肉, 居酒屋 (酒館), 便當',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期三'},
#  {'rating': '3.07',
#   'name': '鹿兒島劇場',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46017452/',
#   'area_genre': '天文館通車站 210m / 居酒屋 (酒館), 海鮮, 涮涮鍋',
#   'price_lunch': 'JPY 2,000 - JPY 2,999',
#   'price_dinner': 'JPY 2,000 - JPY 2,999',
#   'holiday': '-'},
#  {'rating': '3.02',
#   'name': '西鄉Don 東千石店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46018322/',
#   'area_genre': '高见马场車站 177m / 居酒屋 (酒館), 炸豬排, 壽司',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期一'},
#  {'rating': '3.17',
#   'name': '包廂燒肉 牛道 Hanare',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46012415/',
#   'area_genre': '天文館通車站 224m / 燒肉, 涮涮鍋, 壽喜燒',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.05',
#   'name': '全席個室居酒屋 Wa none 鹿兒島天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46014385/',
#   'area_genre': '天文館通車站 139m / 居酒屋 (酒館), 海鮮, 日式火鍋',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': '鹿兒島縣產A5等級黑毛和牛 全席完全個室 牛一彩 天文館店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46010542/',
#   'area_genre': '天文館通車站 367m / 燒肉, 壽喜燒, 涮涮鍋',
#   'price_lunch': 'JPY 1,000 - JPY 1,999',
#   'price_dinner': 'JPY 5,000 - JPY 5,999',
#   'holiday': '-'},
#  {'rating': '3.35',
#   'name': 'Miyama本舖 國分店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4603/A460301/46001667/',
#   'area_genre': '國分車站 708m / 居酒屋 (酒館), 烤雞肉串, 燒肉',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.09',
#   'name': '鐵板 薊 鹿兒島店',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46016951/',
#   'area_genre': '天文館通車站 76m / 居酒屋 (酒館), 鐵板燒, 海鮮',
#   'price_lunch': 'JPY 3,000 - JPY 3,999',
#   'price_dinner': 'JPY 10,000 - JPY 14,999',
#   'holiday': '-'},
#  {'rating': '3.56',
#   'name': '太郎壽司',
#   'link': 'https://tabelog.com/tw/kagoshima/A4602/A460203/46002327/',
#   'area_genre': '阿久根車站 310m / 壽司, 海鮮, 鰻魚',
#   'price_lunch': 'JPY 2,000 - JPY 2,999',
#   'price_dinner': 'JPY 4,000 - JPY 4,999',
#   'holiday': '-'},
#  {'rating': '3.39',
#   'name': '燒酎 酒々藏',
#   'link': 'https://tabelog.com/tw/kagoshima/A4601/A460101/46000160/',
#   'area_genre': '天文館通車站 189m / 居酒屋 (酒館), 海鮮, 郷土料理',
#   'price_lunch': '-',
#   'price_dinner': 'JPY 3,000 - JPY 3,999',
#   'holiday': '星期日'}]
