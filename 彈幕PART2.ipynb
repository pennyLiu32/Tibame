# %% [markdown]
# <a href="https://colab.research.google.com/github/pennyLiu32/Tibame/blob/main/%E5%BD%88%E5%B9%95PART2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import json
import pandas as pd

def save_danmu_to_csv(sn):
    # url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn={}&geo=TW%2CHK".format(sn)
    url = f"https://api.gamer.com.tw/anime/v1/danmu.php?videoSn={sn}&geo=TW%2CHK"
    f = req.urlopen(url)
    content = f.read()
    content = json.loads(content)

    danmus = content["data"]["danmu"]

    df = pd.DataFrame(danmus)
    df.to_csv("baha.csv", encoding="utf-8", index=False)
    return df

save_danmu_to_csv("26850")
# Out:
#                    text    color  size  position   time        sn      userid
# 0              看完2刷2/15  #FFFFFF     1         0      0  25410397  amanda4a03
# 1                 好帥\n簽  #FFFFFF     1         2      0  25652598   s52241110
# 2                  油鍋篇！  #0036FA     2         2      0  29426133    Lucian01
# 3                     我  #FDE53D     1         0      0  33663511  kh69xvvspn
# 4     看封面就知道本片不適合老少咸宜觀看  #FF9625     2         2      6  45407686    d7261904
# ...                 ...      ...   ...       ...    ...       ...         ...
# 2996          善意什麼時候解開的  #FFFFFF     1         0  28053  28932406  safiya0820
# 2997     樓下白字說得對，沒有一個正常  #FFFFFF     1         0  28065  49967935    abcd7849
# 2998                 油鍋  #FFFFFF     1         0  28110  25430419   b30838695
# 2999               嗨\n嗨  #A7FE39     1         0  28119  27845675     coco447
# 3000        2025.7.27 *  #FFFFFF     1         0  28119  45877991     s935602
#
# [3001 rows x 7 columns]

# %% [markdown]
# - 2: 成功
# - 3: 轉址
# - 4: 失敗
#     - 404: Not Fount
#     - 403: Forbidden
#         - IP ban
#
# - 送出: 網址+headers
# - 回應: 回應+headers
#
# - HTML:無數長方形(區塊)所構成
#
# ```python(html)
# <>開始
#
# </>結束
#
# 1. 名稱: 決定是甚麼
#     a-> 超連結 img-> 圖片 video->影片
#
# 2. 屬性: 決定細節
#     a href="網址"
#     img/video scr="網址"
#         <a href="網址">開始
#         顯示內容
#         </a>
# 3. 顯示內容
# ```

# %%
import urllib.request as req
# 這裡被擋是因為巴哈擋國外IP，所以在COLAB上執行會被拒絕
# url = "https://ani.gamer.com.tw/animeVideo.php?sn=26850"
url = "https://github.com/Elwing-Chou/tibame_20260714/raw/refs/heads/main/baha.html"
h = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36"
}
r = req.Request(url, headers=h)
f = req.urlopen(r)
content = f.read()
content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="zh-Hant-TW" data-theme="light" data-geo="TW">\r\n<head>\r\n<title>\xe9\xac\xbc\xe6\xbb\x85\xe4\xb9\x8b\xe5\x88\x83 \xe9\x81\x8a\xe9\x83\xad\xe7\xaf\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b - \xe5\xb7\xb4\xe5\x93\x88\xe5\xa7\x86\xe7\x89\xb9\xe5\x8b\x95\xe7\x95\xab\xe7\x98\x8b</title>\r\n<meta http-equiv="Content-Type" content="text/html" charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\r\n<meta name="description" content="\xe9\xac\xbc\xe6\xbb\x85\xe4\xb9\x8b\xe5\x88\x83 \xe9\x81\x8a\xe9\x83\xad\xe7\xaf\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b! ">\r\n<meta name="thumbnail" content="https://p2.bahamut.com.tw/B/2KU/31/d475e027a2a552278cf8fa4eb11ekpb5.JPG">\r\n<meta property="og:title" content="\xe9\xac\xbc\xe6\xbb\x85\xe4\xb9\x8b\xe5\x88\x83 \xe9\x81\x8a\xe9\x83\xad\xe7\xaf\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b">\r\n<meta property="og:type" content="website">\r\n<meta property="og:url" content="https://ani.gamer.com.tw/animeVideo.php?sn=26850">\r\n<meta property="og:image" content="https://p2.bahamut.com.tw/B/2KU/31/d475e027a2a552278cf8fa4eb11ekpb5.JPG">\r\n<meta property="og:description" content="\xe9\xac\xbc\xe6\xbb\x85\xe4\xb9\x8b\xe5\x88\x83 \xe9\x81\x8a\xe9\x83\xad\xe7\xaf\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b! \x ...
